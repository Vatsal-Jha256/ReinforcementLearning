# %%
# %%capture
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# %%capture
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5" -O ./training-envs-executables/linux/SnowballTarget.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-12-16 09:46:24--  https://docs.google.com/uc?export=download&confirm=t&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5
# Resolving docs.google.com (docs.google.com)... 142.251.18.113, 142.251.18.139, 142.251.18.101, ...
# Connecting to docs.google.com (docs.google.com)|142.251.18.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1uhc458qt3jtv35bk6n6jkclru79cbgq/1702719975000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=cb375e4c-b6c8-459d-8452-595ad152aa76 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-16 09:46:25--  https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1uhc458qt3jtv35bk6n6jkclru79cbgq/1702719975000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=cb375e4c-b6c8-459d-8452-595ad152aa76
# Resolving doc-14-28-docs.googleusercontent.com (doc-14-28-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to doc-14-28-docs.googleusercontent.com (doc-14-28-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35134213 (34M) [application/x-zip-compressed]
# Saving to: ‘./training-envs-executables/linux/SnowballTarget.zip’
#
# ./training-envs-exe 100%[===================>]  33.51M   185MB/s    in 0.2s
#
# 2023-12-16 09:46:25 (185 MB/s) - ‘./training-envs-executables/linux/SnowballTarget.zip’ saved [35134213/35134213]

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %%
import os
cwd= os.getcwd()
print (cwd)
# Out:
# /content/ml-agents/ml-agents/ml-agents

# %%
# !mlagents-learn ./config/ppo/SnowballTarget.yaml --env=./training-envs-executables/linux/SnowballTarget/SnowballTarget --run-id="SnowballTarget1" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0.dev0,
#   ml-agents-envs: 1.1.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.1.2+cu121
# [INFO] Connected to Unity environment with package version 2.1.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: SnowballTarget?team=0
# [INFO] Hyperparameters for behavior name SnowballTarget:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	50000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	256
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	10
# 	even_checkpoints:	False
# 	max_steps:	200000
# 	time_horizon:	64
# 	summary_freq:	10000
# 	threaded:	True
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] SnowballTarget. Step: 10000. Time Elapsed: 34.048 s. Mean Reward: 3.932. Std of Reward: 1.982. Training.
# [INFO] SnowballTarget. Step: 20000. Time Elapsed: 65.350 s. Mean Reward: 6.891. Std of Reward: 2.556. Training.
# [INFO] SnowballTarget. Step: 30000. Time Elapsed: 93.585 s. Mean Reward: 9.273. Std of Reward: 3.292. Training.
# [INFO] SnowballTarget. Step: 40000. Time Elapsed: 124.292 s. Mean Reward: 11.309. Std of Reward: 2.607. Training.
# [INFO] SnowballTarget. Step: 50000. Time Elapsed: 153.604 s. Mean Reward: 12.773. Std of Reward: 2.811. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-49936.onnx
# [INFO] SnowballTarget. Step: 60000. Time Elapsed: 184.726 s. Mean Reward: 14.727. Std of Reward: 2.490. Training.
# [INFO] SnowballTarget. Step: 70000. Time Elapsed: 214.443 s. Mean Reward: 15.705. Std of Reward: 1.995. Training.
# [INFO] SnowballTarget. Step: 80000. Time Elapsed: 246.045 s. Mean Reward: 17.564. Std of Reward: 2.418. Training.
# [INFO] SnowballTarget. Step: 90000. Time Elapsed: 276.736 s. Mean Reward: 19.023. Std of Reward: 1.925. Training.
# [INFO] SnowballTarget. Step: 100000. Time Elapsed: 311.914 s. Mean Reward: 19.873. Std of Reward: 2.523. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-99960.onnx
# [INFO] SnowballTarget. Step: 110000. Time Elapsed: 342.927 s. Mean Reward: 21.019. Std of Reward: 2.369. Training.
# [INFO] SnowballTarget. Step: 120000. Time Elapsed: 370.696 s. Mean Reward: 22.867. Std of Reward: 2.353. Training.
# [INFO] SnowballTarget. Step: 130000. Time Elapsed: 402.086 s. Mean Reward: 23.364. Std of Reward: 2.739. Training.
# [INFO] SnowballTarget. Step: 140000. Time Elapsed: 430.424 s. Mean Reward: 23.455. Std of Reward: 2.320. Training.
# [INFO] SnowballTarget. Step: 150000. Time Elapsed: 461.101 s. Mean Reward: 24.036. Std of Reward: 2.501. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-149984.onnx
# [INFO] SnowballTarget. Step: 160000. Time Elapsed: 490.286 s. Mean Reward: 23.977. Std of Reward: 2.491. Training.
# [INFO] SnowballTarget. Step: 170000. Time Elapsed: 519.723 s. Mean Reward: 24.800. Std of Reward: 2.110. Training.
# [INFO] SnowballTarget. Step: 180000. Time Elapsed: 549.712 s. Mean Reward: 24.659. Std of Reward: 2.393. Training.
# [INFO] SnowballTarget. Step: 190000. Time Elapsed: 580.729 s. Mean Reward: 25.000. Std of Reward: 1.809. Training.
# [INFO] SnowballTarget. Step: 200000. Time Elapsed: 608.841 s. Mean Reward: 24.795. Std of Reward: 2.399. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-199984.onnx
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx
# [INFO] Copied results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx to results/SnowballTarget1/SnowballTarget.onnx.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="VATSAL1729/ppo-SnowballTarget" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget1 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget1 to the Hugging Face Hub
# SnowballTarget-149984.onnx:   0% 0.00/651k [00:00<?, ?B/s]
# SnowballTarget-149984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
# SnowballTarget-199984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
#
#
# Upload 13 LFS files:   0% 0/13 [00:00<?, ?it/s]
#
#
#
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
# SnowballTarget-149984.pt:   0% 16.4k/3.85M [00:00<02:04, 30.9kB/s]
#
# SnowballTarget.onnx:   3% 16.4k/651k [00:00<00:22, 28.7kB/s]
#
#
#
#
# SnowballTarget.onnx:   3% 16.4k/651k [00:00<00:22, 28.8kB/s]
#
#
# SnowballTarget-149984.onnx:   3% 16.4k/651k [00:00<00:23, 27.3kB/s]
#
#
# SnowballTarget.onnx: 100% 651k/651k [00:01<00:00, 600kB/s]
# SnowballTarget-149984.pt: 100% 3.85M/3.85M [00:01<00:00, 3.41MB/s]
# SnowballTarget-149984.onnx: 100% 651k/651k [00:01<00:00, 482kB/s]
# SnowballTarget.onnx: 100% 651k/651k [00:01<00:00, 458kB/s]
#
# SnowballTarget-200112.pt:  72% 2.75M/3.85M [00:00<00:00, 26.1MB/s]
#
#
#
# Upload 13 LFS files:   8% 1/13 [00:01<00:19,  1.62s/it]
#
# SnowballTarget-49936.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
#
#
#
# SnowballTarget-199984.pt: 100% 3.85M/3.85M [00:01<00:00, 2.31MB/s]
#
#
#
#
# Upload 13 LFS files:  31% 4/13 [00:01<00:03,  2.57it/s]
#
#
# SnowballTarget-49936.onnx: 100% 651k/651k [00:00<00:00, 767kB/s]
#
# SnowballTarget-200112.pt: 100% 3.85M/3.85M [00:01<00:00, 3.63MB/s]
# SnowballTarget-99960.onnx: 100% 651k/651k [00:00<00:00, 825kB/s]
# events.out.tfevents.1702720131.24d7b95accd3.17601.0:   0% 0.00/23.7k [00:00<?, ?B/s]
#
#
#
# Upload 13 LFS files:  46% 6/13 [00:02<00:02,  2.71it/s]
#
#
#
#
# SnowballTarget-49936.pt: 100% 3.85M/3.85M [00:01<00:00, 3.67MB/s]
#
#
#
#
# SnowballTarget-99960.pt: 100% 3.85M/3.85M [00:01<00:00, 3.56MB/s]
# events.out.tfevents.1702720131.24d7b95accd3.17601.0: 100% 23.7k/23.7k [00:00<00:00, 55.6kB/s]
#
#
#
#
# SnowballTarget.onnx: 100% 651k/651k [00:00<00:00, 795kB/s]
# checkpoint.pt: 100% 3.85M/3.85M [00:01<00:00, 3.21MB/s]
#
#
#
#
# Upload 13 LFS files: 100% 13/13 [00:03<00:00,  3.44it/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/VATSAL1729/ppo-SnowballTarget
